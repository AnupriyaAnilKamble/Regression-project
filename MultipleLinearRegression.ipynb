# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('CarPrice_Assignment_Multiregression.csv')
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df.shape
# Out:
# (205, 26)

# %%
df['CarName'].value_counts()
# Out:
# CarName
# toyota corona           6
# toyota corolla          6
# peugeot 504             6
# subaru dl               4
# mitsubishi mirage g4    3
#                        ..
# mazda glc 4             1
# mazda rx2 coupe         1
# maxda glc deluxe        1
# maxda rx3               1
# volvo 246               1
# Name: count, Length: 147, dtype: int64

# %%
df['fueltype'].value_counts()
# Out:
# fueltype
# gas       185
# diesel     20
# Name: count, dtype: int64

# %%
df['aspiration'].value_counts()
# Out:
# aspiration
# std      168
# turbo     37
# Name: count, dtype: int64

# %%
df['fuelsystem'].value_counts()
# Out:
# fuelsystem
# mpfi    94
# 2bbl    66
# idi     20
# 1bbl    11
# spdi     9
# 4bbl     3
# mfi      1
# spfi     1
# Name: count, dtype: int64

# %%
categorical = [var for var in df.columns if df[var].dtype == 'O']
categorical
# Out:
# ['CarName',
#  'fueltype',
#  'aspiration',
#  'doornumber',
#  'carbody',
#  'drivewheel',
#  'enginelocation',
#  'enginetype',
#  'cylindernumber',
#  'fuelsystem']

# %%
Numerical = [var for var in df.columns if df[var].dtype != 'O']
Numerical
# Out:
# ['car_ID',
#  'symboling',
#  'wheelbase',
#  'carlength',
#  'carwidth',
#  'carheight',
#  'curbweight',
#  'enginesize',
#  'boreratio',
#  'stroke',
#  'compressionratio',
#  'horsepower',
#  'peakrpm',
#  'citympg',
#  'highwaympg',
#  'price']

# %% [markdown]
# #### Normalization

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# !pip install scikit-learn

# %%
min_max = MinMaxScaler()
min_max.fit(df[['wheelbase','enginesize','boreratio','stroke','compressionratio','horsepower','peakrpm','citympg','highwaympg']])
# Out:
# MinMaxScaler()

# %%
X = df[['wheelbase','enginesize','boreratio','stroke','compressionratio','horsepower','peakrpm','citympg','highwaympg']]
X
# Out:
#      wheelbase  enginesize  boreratio  stroke  compressionratio  horsepower  \
# 0         88.6         130       3.47    2.68               9.0         111
# 1         88.6         130       3.47    2.68               9.0         111
# 2         94.5         152       2.68    3.47               9.0         154
# 3         99.8         109       3.19    3.40              10.0         102
# 4         99.4         136       3.19    3.40               8.0         115
# ..         ...         ...        ...     ...               ...         ...
# 200      109.1         141       3.78    3.15               9.5         114
# 201      109.1         141       3.78    3.15               8.7         160
# 202      109.1         173       3.58    2.87               8.8         134
# 203      109.1         145       3.01    3.40              23.0         106
# 204      109.1         141       3.78    3.15               9.5         114
#
#      peakrpm  citympg  highwaympg
# ...

# %%
y = df['price']
y
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 205, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=10)

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([10171.9484323 , 18095.24554416, 12528.49167399,  6658.93860929,
#        54456.92651747,  9735.03187029,  6527.643598  , 14386.97362415,
#         6504.91054532, 20639.04727573, 15790.19772698,  8708.20663629,
#        10516.25065623, 17188.32906655, 37632.8394785 , 24260.99928998,
#         9735.03187029, 17266.67241616, 14499.76752317, 20339.81636417,
#         7873.93413859, 13591.09551218, 14386.97362415, 23542.06600586,
#        16689.4461184 , 18845.49259004, 10841.62075936,  6527.643598  ,
#         9879.54258003, 24260.99928998,  6487.77945971,  5783.27000995,
#         5887.91815708, 10447.26365143, 24871.75367216, 24032.4551735 ,
#        10289.43519132, 24401.39813037, 11548.67273083,  6208.39049602,
#         8799.79519591])

# %%
y_test
# Out:
# 131     9895.0
# 117    18150.0
# 63     10795.0
# 56     11845.0
# 49     36000.0
# 60      8495.0
# 19      6295.0
# 171    11549.0
# 163     8058.0
# 203    22470.0
# 5      15250.0
# 173     8948.0
# 159     7788.0
# 114    17075.0
# 129    31400.5
# 101    13499.0
# 61     10595.0
# 116    17950.0
# 1      16500.0
# 2      16500.0
# 35      7295.0
# 10     16430.0
# 167     8449.0
# 178    16558.0
# 6      17710.0
# 75     16503.0
# 99      8949.0
# 20      6575.0
# 39      8845.0
# 102    14399.0
# 95      7799.0
# 154     7898.0
# 52      6795.0
# 58     15645.0
# 70     31600.0
# 68     28248.0
# 46     11048.0
# 103    13499.0
# 147    10198.0
# 76      5389.0
# 176    10898.0
# Name: price, dtype: float64

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_pred,y_test)
mse
# Out:
# 24213377.84850262

# %%
from sklearn.metrics import mean_squared_error
mse = np.sqrt(mean_squared_error(y_pred,y_test))
mse
# Out:
# 4920.709079848413

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_pred,y_test)
mae
# Out:
# 3179.155182531567

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_pred,y_test)
mape
# Out:
# 0.19290675481821318
